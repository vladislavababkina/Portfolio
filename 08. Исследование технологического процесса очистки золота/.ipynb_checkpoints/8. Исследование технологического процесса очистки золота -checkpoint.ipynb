# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Ознакомление-с-данными" data-toc-modified-id="Ознакомление-с-данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ознакомление с данными</a></span></li><li><span><a href="#Проверка-рассчета-эффективности" data-toc-modified-id="Проверка-рассчета-эффективности-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка рассчета эффективности</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Распределение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Распределение концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Выбор-модели" data-toc-modified-id="Выбор-модели-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выбор модели</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# **Описание данных**
#
# *Технологический процесс*
#
# -  Rougher feed — исходное сырье
# -  Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# -  Xanthate **— ксантогенат (промотер, или активатор флотации);
# -  Sulphate — сульфат (на данном производстве сульфид натрия);
# -  Depressant — депрессант (силикат натрия).
# -  Rougher process (англ. «грубый процесс») — флотация
# -  Rougher tails — отвальные хвосты
# -  Float banks — флотационная установка
# -  Cleaner process — очистка
# -  Rougher Au — черновой концентрат золота
# -  Final Au — финальный концентрат золота
#
# *Параметры этапов*
#
# -  air amount — объём воздуха
# -  fluid levels — уровень жидкости
# -  feed size — размер гранул сырья
# -  feed rate — скорость подачи
# *Наименование признаков*
#
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
#
# *Возможные значения для блока [этап]:*
#
# -  rougher — флотация
# -  primary_cleaner — первичная очистка
# -  secondary_cleaner — вторичная очистка
# -  final — финальные характеристики
#
# *Возможные значения для блока [тип_параметра]:*
#
# -  input — параметры сырья
# -  output — параметры продукта
# -  state — параметры, характеризующие текущее состояние этапа
# -  calculation — расчётные характеристики
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression
from sklearn.metrics import  mean_absolute_error, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor

from tqdm.notebook import tqdm
from time import sleep

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Ознакомление с данными

# %%
data = pd.read_csv('/datasets/gold_recovery_full_new.csv')
train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
def information (data):
    display(data.head())
    print('\033[1m'+'Общая информация о данных:'+'\033[0m','\n')
    print(data.info(),'\n')
    print('\033[1m'+'Наличие пропусков в данных:'+'\033[0m','\n')
    print(data.isna().sum(),'\n')
    print('\033[1m'+'Наличие явных дубликатов:'+'\033[0m','\n')
    print(data.duplicated().sum(),'\n')
    print('\033[1m'+'Описательная статистика'+'\033[0m','\n')
    display(data.describe())

# %%
pd.set_option('display.max_columns', 87)
pd.set_option('display.max_rows', 87)

# %%
information(data)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
information(train)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
information(test)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# Наименование столбцов впорядке, явных дубликатов нет,имееются большое количество пропусков в разных столбцах.\
# В данных на выходных этапах имеются нулевые значения,нужно детальнее рассмотреть.\
# Так же тестовая выборка содержит не все признаки,что есть в исходном и обучающем наборе данных.

# %% [markdown]
# ### Проверка рассчета эффективности

# %% [markdown]
# Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE(средняя абсолютная ошибка) между нашими расчётами и значением признака

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле
# ![image.png](attachment:image.png)
#
# где:
# -  C — доля золота в концентрате после флотации/очистки(**'rougher.output.concentrate_au'**);
# -  F — доля золота в сырье/концентрате до флотации/очистки(**'rougher.input.feed_au'**);
# -  T — доля золота в отвальных хвостах после флотации/очистки(**'rougher.output.tail_au '**).

# %%
train['recovery'] = ((train['rougher.output.concentrate_au']*(train['rougher.input.feed_au']-train['rougher.output.tail_au']))/
(train['rougher.input.feed_au']*(train['rougher.output.concentrate_au']-train['rougher.output.tail_au']))*100)

# %%
train[['recovery','rougher.output.recovery']]
# Out:
#         recovery  rougher.output.recovery
# 0      87.107763                87.107763
# 1      86.843261                86.843261
# 2      86.842308                86.842308
# 3      87.226430                87.226430
# 4      86.688794                86.688794
# ...          ...                      ...
# 14144  89.574376                89.574376
# 14145  87.724007                87.724007
# 14146  88.890579                88.890579
# 14147  89.858126                89.858126
# 14148  89.514960                89.514960
#
# [14149 rows x 2 columns]

# %%
print('Среднее абсолютное отклонение равно:', mean_absolute_error(train['recovery'],train['rougher.output.recovery']))
# Out:
# Среднее абсолютное отклонение равно: 9.73512347450521e-15

# %% [markdown]
# Среднее абсолютное отклонение между нашими рассчетами и признаком в данных стремится к нулю и составляет 9.7е-15, что говорит о правильности рассчетов эффективности обогащения в данных.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке

# %%
data_col = data.columns.values.tolist ()
test_col = test.columns.values.tolist ()

# %%
differences = []
for i in data_col:
    if i not in test_col:
        differences.append(i)

# %%
differences
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Видим,что в тестовом наборе нет целевых признаков **'final.output.recovery'** и **'rougher.output.recovery'**.\
# Так же в тестовом наборе отстутствуют выходные параметы продукта на каждой из стадий обработки, вероятно это связано с тем,что они замеряются позже.\
# Предположу,что если бы мы знали данные парметры заранее, то нам не понадобилась бы модель для предсказаний,поскольку мы бы могли посчитать эффективность обогащения просто по формуле.

# %% [markdown]
#  ### Предобработка данных

# %% [markdown]
# Заполним пропуски методом ffill, исходя из информации:\
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.

# %%
data = data.ffill(axis=0)
train = train.ffill(axis=0)
test = test.ffill(axis=0)
train.isna().sum()
# Out:
# date                                          0
# final.output.concentrate_ag                   0
# final.output.concentrate_pb                   0
# final.output.concentrate_sol                  0
# final.output.concentrate_au                   0
#                                              ..
# secondary_cleaner.state.floatbank5_b_air      0
# secondary_cleaner.state.floatbank5_b_level    0
# secondary_cleaner.state.floatbank6_a_air      0
# secondary_cleaner.state.floatbank6_a_level    0
# recovery                                      0
# Length: 88, dtype: int64

# %% [markdown]
# Добавим целевые признаки в тестовый датафрейм.

# %%
test = test.merge(data[['final.output.recovery','rougher.output.recovery','date']], on = 'date')
test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# Удалю признак дата из тренировочного и тестового набора, поскольку считаю, что они не влияют на обучение модели.

# %%
test = test.drop(['date'],axis=1)
train = train.drop(['date'],axis=1)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Распределение концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
au_data = data[['final.output.concentrate_au','primary_cleaner.output.concentrate_au','rougher.output.concentrate_au']]
ag_data = data[['final.output.concentrate_ag','primary_cleaner.output.concentrate_ag','rougher.output.concentrate_ag']]
pb_data = data[['final.output.concentrate_pb','primary_cleaner.output.concentrate_pb','rougher.output.concentrate_pb']]

# %%
def concentration (df,mettal):
   
    '''Функция строит график плотности распределения металла на стадиях обработки'''
    
    plt.figure(figsize=(13,8))
    sns.displot(df,kind="kde",fill=True)
    
    plt.title(f'Концентрация {mettal} на стадиях обработки ',fontsize=15)
    plt.xlabel(f'Концетрация {mettal} в %')
    plt.ylabel('Количество')
    plt.show

# %%
def box (df,mettal):
    
    '''Функция строит диаграмму распределения металла на стадиях обработки'''
    
    sns.boxplot(data=df, showfliers=False,width= 0.7)
    plt.xticks(rotation=30)
    plt.title(f'Диаграмма распределений {mettal} на стадиях обработки ',fontsize=15)
    plt.xlabel('Этапы')
    plt.ylabel(f'Концетрация {mettal} в %')
    plt.show

# %%
concentration(au_data,'Au')

# %%
concentration(ag_data,'Ag')

# %%
concentration(pb_data,'Pb')

# %%
box(au_data,'Au')

# %%
box(ag_data,'Ag')

# %%
box(pb_data,'Pb')

# %% [markdown]
# Концентрация золота(Au) растет на каждом из этапов обработки, концентрация серебра (Ag) наоборот падает.Содержания свинца (Pb) немного увеличивается после флотации и далее остается практически неизменным в последующих этапах.\
# Так же видим, что на всех стадиях очистки по каждому из металлов в данных содержатся околонулевые значения.

# %% [markdown]
# ###  Распределение размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# Необходимо сравнить распределение гранул в тестовой и обучающей выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
def feed_size (stage,name):
    plt.figure(figsize=(13,8))
    sns.histplot(data=train, x=stage, bins=50,stat='density',alpha=0.8)
    sns.histplot(data=test, x=stage, bins=50,stat='density',color='yellow',alpha=0.4)
    plt.title(f'Размер гранул на этапе {name}',fontsize=15)
    plt.xlabel('Размер гранул')
    plt.ylabel('Плотность')
    plt.legend(['train','test'])
    plt.show

# %%
feed_size('primary_cleaner.input.feed_size','Первичной очистки')

# %%
feed_size('rougher.input.feed_size','Флотации')

# %% [markdown]
# Видим,что распределение размера гранул сырья в тренировочной и тестовой выборках на этапах флотации и первичной очистки существенно не различаются,значит оценка модели должна быть правильной.

# %% [markdown]
#  ### Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
sum_conc = pd.DataFrame()
sum_conc['rougher_input'] = data[['rougher.input.feed_ag','rougher.input.feed_pb','rougher.input.feed_au','rougher.input.feed_sol']].sum(axis=1)
sum_conc['rougher_output'] =data[['rougher.output.concentrate_ag','rougher.output.concentrate_pb','rougher.output.concentrate_sol','rougher.output.concentrate_au']].sum(axis=1)
sum_conc['final_output'] =data[['final.output.concentrate_ag','final.output.concentrate_pb','final.output.concentrate_sol','final.output.concentrate_au']].sum(axis=1)

# %%
sum_conc.head()
# Out:
#    rougher_input  rougher_output  final_output
# 0      51.680034       66.424950     63.644396
# 1      50.659114       67.012710     63.957723
# 2      50.609929       66.103793     64.311180
# 3      51.061546       65.752751     63.573449
# 4      47.859163       65.908382     64.004667

# %%
plt.figure(figsize=(13,8))
sns.histplot(data=sum_conc, x='rougher_input', bins=50)
sns.histplot(data=sum_conc, x='rougher_output', bins=50,color='pink')
sns.histplot(data=sum_conc, x='final_output', bins=50,color='grey')
plt.title('Суммарная концентрация веществ',fontsize=15)
plt.xlabel('Концентрация веществ в %')
plt.ylabel('Количество')
plt.legend(['rougher_input','rougher_output','final_output'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Концентрация веществ после флотации увеличилась,но разброс значений все еще такой же большой как и до нее.В финальном концентрате данные имеют значительно меньший разброс,хотя в целом средние значения схожи с предыдущим этапом .\
# Так же стоит отметить наличие выбросов в районе нуля и длинный хвос в распределении от 0 до 30.Посмотрим на диаграмму распределений.

# %%
sns.boxplot(data=sum_conc, showfliers=False,width= 0.7)
plt.title(f'Диаграмма распределений суммарной концентрации веществ на стадиях обработки ',fontsize=15)
plt.xlabel('Этапы')
plt.ylabel(f'Концетрация в %')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Уберем из данных значения,где суммарная концентрация веществ меньше 10% , не убираем больше, с целью не потерять  большое количество данных, важно избавиться от скачка в районе нуля.

# %%
def sum_concentr (df):
    df['rougher_input_sum'] = df[['rougher.input.feed_ag','rougher.input.feed_pb','rougher.input.feed_au','rougher.input.feed_sol']].sum(axis=1)
    df['rougher_output_sum'] =df[['rougher.output.concentrate_ag','rougher.output.concentrate_pb','rougher.output.concentrate_sol','rougher.output.concentrate_au']].sum(axis=1)
    df['final_output_sum'] =df[['final.output.concentrate_ag','final.output.concentrate_pb','final.output.concentrate_sol','final.output.concentrate_au']].sum(axis=1)

# %%
sum_concentr(train)
train=train.drop(['recovery'],axis=1)
train = train[(train['rougher_input_sum'] > 10) & (train['rougher_output_sum'] > 10) & (train['final_output_sum'] > 10)]
train = train.drop(['rougher_input_sum', 'rougher_output_sum', 'final_output_sum'], axis=1)
train.head()
# Out:
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.concentrate_au  \
# 0                      5.507324                    42.192020
# 1                      5.257781                    42.701629
# 2                      5.383759                    42.657501
# 3                      4.858634                    42.689819
# 4                      4.939416                    42.774141
#
#    final.output.recovery  final.output.tail_ag  final.output.tail_pb  \
# 0              70.541216             10.411962              0.895447
# 1              69.266198             10.462676              0.927452
# ...

# %% [markdown]
# Поскольку в тесте отсутвуют данные о выходных параметрах после каждого этапа,то и в обучающей выборке стоит их убрать, так как прогноз будет строится исходя из входных параметров на этапах обработки руды.

# %%
train = train.loc[:, list(test.columns)]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13783 entries, 0 to 14148
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               13783 non-null  float64
#  1   primary_cleaner.input.depressant            13783 non-null  float64
#  2   primary_cleaner.input.feed_size             13783 non-null  float64
#  3   primary_cleaner.input.xanthate              13783 non-null  float64
#  4   primary_cleaner.state.floatbank8_a_air      13783 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_level    13783 non-null  float64
#  6   primary_cleaner.state.floatbank8_b_air      13783 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_level    13783 non-null  float64
#  8   primary_cleaner.state.floatbank8_c_air      13783 non-null  float64
# ...

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# Для решения задачи введём новую метрику качества — **sMAPE** (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).\
# Она выражается  в относительных величинах и одинаково учитывает масштаб и целевого признака, и предсказания.\
# ![image-2.png](attachment:image-2.png)

# %%
def sMAPE(y_true, y_pred):
    sMAPE = (sum(abs(y_true-y_pred)/((abs(y_true)+abs(y_pred))/2))/len(y_true))*100
    return sMAPE
 
smape = make_scorer(sMAPE)

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
# -  эффективность обогащения чернового концентрата rougher.output.recovery;
# -  эффективность обогащения финального концентрата final.output.recovery.\
# Итоговая метрика складывается из двух величин:\
# ![image.png](attachment:image.png)

# %%
#Разобьем выборки на признаки и таргет
features_train = train.drop(columns=['rougher.output.recovery','final.output.recovery'], axis=1)
target_train = train[['rougher.output.recovery','final.output.recovery']]

features_test = test.drop(columns=['rougher.output.recovery','final.output.recovery'], axis=1)
target_test = test[['rougher.output.recovery','final.output.recovery']]

# %% [markdown]
# Посмотрим на признаки и их влияние на целевые

# %%
X = features_train
y = target_train['rougher.output.recovery']
mi = mutual_info_regression(X,y, random_state=42)
plt.figure(figsize = (15,8))
ax = sns.barplot(x=X.columns.tolist(), y=mi)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %%
X = features_train
y = target_train['final.output.recovery']
mi = mutual_info_regression(X,y, random_state=42)
plt.figure(figsize = (15,8))
ax = sns.barplot(x=X.columns.tolist(), y=mi)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# Как видим все выбранные признаки имеют влияение на таргеты, какие-то меньше,но нулевых нет.

# %%
#Поскольку планируется использование модели случайного леса,признаки необходимо масштабировать.
scaler = StandardScaler()
scaler.fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# ### Выбор модели

# %% [markdown]
# Проверим итоговый sMAPE на линейоной регресии, случайном лесе и дереве решений.

# %%
print('\033[94m'+'—'*80)
print("Linear Regression")
print('\033[94m'+'—'*80)
model = LinearRegression()
scores_rougher = cross_val_score(model, features_train, target_train['rougher.output.recovery'], scoring=smape, cv=5) 
scores_final = cross_val_score(model, features_train, target_train['final.output.recovery'], scoring=smape, cv=5) 
final_score_linear = pd.Series(0.25*scores_rougher+0.75*scores_final).mean()
print('Средняя оценка качества модели:', final_score_linear)
# Out:
# ————————————————————————————————————————————————————————————————————————————————
# Linear Regression
# ————————————————————————————————————————————————————————————————————————————————
# Средняя оценка качества модели: 10.029544166382276

# %%
# %%time
#Подберем сначала глубину деревьев при произвольном количестве деревьев
best_result = 1000
best_depth = 0
for depth in tqdm (range(1, 16, 1)):
    sleep(0.5)
    model = RandomForestRegressor(n_estimators=10, max_depth=depth, random_state=12345)
    scores_rougher = cross_val_score(model, features_train, target_train['rougher.output.recovery'], scoring=smape, cv=5) 
    scores_final = cross_val_score(model, features_train, target_train['final.output.recovery'], scoring=smape, cv=5) 
    final_score = pd.Series(0.25*scores_rougher+0.75*scores_final).mean()
    if final_score < best_result:
        best_depth = depth
        best_result = final_score

print('\033[94m'+'—'*80)
print("RandomForestRegressor")
print('\033[94m'+'—'*80)
print(f'max_depth_RF = {best_depth}, max_score = {best_result}')
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ————————————————————————————————————————————————————————————————————————————————
# RandomForestRegressor
# ————————————————————————————————————————————————————————————————————————————————
# max_depth_RF = 4, max_score = 8.46412982353496
# CPU times: total: 7min 9s
# Wall time: 7min 18s

# %%
# %%time 
#Для глубины 4 подберем количество деревьев

best_result_forest = 1000
best_est = 0
for est in tqdm (range(5, 250,25)):
    model = RandomForestRegressor(n_estimators=est, max_depth=4, random_state=12345)
    scores_rougher = cross_val_score(model, features_train, target_train['rougher.output.recovery'], scoring=smape, cv=5) 
    scores_final = cross_val_score(model, features_train, target_train['final.output.recovery'], scoring=smape, cv=5) 
    final_score = pd.Series(0.25*scores_rougher+0.75*scores_final).mean()
    if final_score < best_result_forest:
        best_est = est
        best_result_forest = final_score

print('\033[94m'+'—'*80)
print("RandomForestRegressor")
print('\033[94m'+'—'*80)
print(f' Средняя оценка качества модели: = {best_result_forest}, max_est_RF = {best_est}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ————————————————————————————————————————————————————————————————————————————————
# RandomForestRegressor
# ————————————————————————————————————————————————————————————————————————————————
#  Средняя оценка качества модели: = 8.402605891475163, max_est_RF = 205
# CPU times: total: 34min 25s
# Wall time: 35min 4s

# %%
# %%time
best_result_tree = 1000
best_depth = 0
for depth in tqdm (range(1, 10)):
    model = DecisionTreeRegressor(random_state=12345, max_depth=depth)
    scores_rougher = cross_val_score(model, features_train, target_train['rougher.output.recovery'], scoring=smape, cv=5) 
    scores_final = cross_val_score(model, features_train, target_train['final.output.recovery'], scoring=smape, cv=5) 
    final_score = pd.Series(0.25*scores_rougher+0.75*scores_final).mean()
    if final_score < best_result_tree:
        best_result_tree = final_score
        best_depth = depth
print('\033[94m'+'—'*80)
print('DecisionTreeRegressor')
print('\033[94m'+'—'*80)
print("Средняя оценка качества модели:", best_result_tree, "Глубина дерева:", best_depth)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ————————————————————————————————————————————————————————————————————————————————
# DecisionTreeRegressor
# ————————————————————————————————————————————————————————————————————————————————
# Средняя оценка качества модели: 8.839298104640765 Глубина дерева: 3
# CPU times: total: 32.8 s
# Wall time: 33.7 s

# %%
result = pd.DataFrame()
result['model']=['Linear Regression','RandomForestRegressor','DecisionTreeRegressor']
result['final_smape'] = [final_score_linear,best_result_forest,best_result_tree]
result.sort_values(by='final_smape')
# Out:
#                    model  final_smape
# 1  RandomForestRegressor     8.402606
# 2  DecisionTreeRegressor     8.839298
# 0      Linear Regression    10.029544

# %% [markdown]
# Лучше всего финальная метрика у модели **RandomForestRegressor(n_estimators=205, max_depth=4, random_state=12345)**.\
# Проверим на тестовой выборке

# %%
best_model = RandomForestRegressor(n_estimators=205, max_depth=4, random_state=12345)
best_model.fit(features_train, target_train)
predictions_test = best_model.predict(features_test)
smape = sMAPE(np.array(target_test),predictions_test)
final_smape = 0.25*smape[0]+0.75*smape[1]
print('Оценка качества лучшей модели на тестовой выборке:',final_smape)
# Out:
# Оценка качества лучшей модели на тестовой выборке: 9.236585149149317

# %% [markdown]
# Проверим адекватность выбранной модели.Сравним с результатами случайной модели.

# %%
dummy_regr = DummyRegressor(strategy="median")
dummy_regr.fit(features_train,target_train)
predictions_dummy = dummy_regr.predict(features_test)
smape_dummy = sMAPE(np.array(target_test),predictions_dummy)
final_smape_dummy = 0.25*smape_dummy[0]+0.75*smape_dummy[1]
print('Оценка качества случайной модели на тестовой выборке:',final_smape_dummy)
# Out:
# Оценка качества случайной модели на тестовой выборке: 9.440067056144144

# %% [markdown]
# Выбранная модель предсказывает лучше случайной всего на 0,2.

# %% [markdown]
# ## Вывод

# %% [markdown]
# Для подготовки прототипа модели машинного обучения по предсказанию коээфициента восстановления золота из золотосодержащей руды было выполнено:
# 1. Проверка правильности рассчетов эффективности в данных(рассчеты в данных корректные)
# 2. Подготовка данных(заполнены пропуски, добавлены целевые признаки в тестовую выборку)
# 3. Исследование распределений металлов и суммарной концентрации вещесвт на каждой из стадий обработки, в процессе которого были обнаружены выбросы в нулевых значениях.Для правильной работы модели, данные с суммарной концентрацией менее 10% были исключены из тренировочной выборки.
# 4. Исследование распределения размеров гранул сырья в тестовой и тренировночй выборках(показало,что распределение граниул существенно не различаются)
# 5. Написана функция для рассчета sMAPE
# 6. Проверка показателя итоговой sMAPE на моделях линейной регрессии, случайного леса и дерева решений. Где лучшей моделью была определена **RandomForestRegressor(n_estimators=205, max_depth=4, random_state=12345)** с итоговой метрикой **на тренировочных данных 8.4**, на **тестовых 9.2**.
# 7. Проверили на сколько лучше выбранная модель предсказывает, чем случайная.**Метрика случайной модели на тестовых данных составила 9.4**, что говорит о том,что выбранная лучшая модель плохо справляется с задачей.
